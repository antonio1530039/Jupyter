# %%
# Imports
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn import datasets
import matplotlib.pyplot as plt
# Load in the ‘digits‘ data
digits = datasets.load_digits()
# Inspect the shape
print digits.data.shape
# Print out the data
print digits.data
# Out:
# (1797L, 64L)
# [[  0.   0.   5. ...,   0.   0.   0.]
#  [  0.   0.   0. ...,  10.   0.   0.]
#  [  0.   0.   0. ...,  16.   9.   0.]
#  ...,
#  [  0.   0.   1. ...,   6.   0.   0.]
#  [  0.   0.   2. ...,  12.   0.   0.]
#  [  0.   0.  10. ...,  12.   1.   0.]]

# %%
pca = PCA(n_components=2)
# Fit and transform the data to the model
reduced_data_pca = pca.fit_transform(digits.data)
# Inspect the shape
print reduced_data_pca.shape
# Print out the data
print reduced_data_pca
# Out:
# (1797L, 2L)
# [[ -1.25946819  21.2748878 ]
#  [  7.95760973 -20.76869746]
#  [  6.99192579  -9.95599166]
#  ...,
#  [ 10.80128409  -6.96025342]
#  [ -4.8720997   12.42395711]
#  [ -0.34438787   6.36554626]]

# %%
# %matplotlib inline
# Visualization
print type(digits.target)
colors = ['black', 'blue', 'purple', 'yellow', 'white',
          'red', 'lime', 'cyan', 'orange', 'gray']
for i in range(len(colors)):
    print digits.target == i
    x = reduced_data_pca[:, 0][digits.target == i]
    y = reduced_data_pca[:, 1][digits.target == i]
    plt.scatter(x, y, c=colors[i])
    plt.legend(digits.target_names, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
    plt.title("PCA Scatter Plot")
plt.show()
# Out:
# <type 'numpy.ndarray'>
# [ True False False ..., False False False]
# [False  True False ..., False False False]
# [False False  True ..., False False False]
# [False False False ..., False False False]
# [False False False ..., False False False]
# [False False False ..., False False False]
# [False False False ..., False False False]
# [False False False ..., False False False]
# [False False False ...,  True False  True]
# [False False False ..., False  True False]

# %%
# Normalize data
normalized_data = normalize(digits.data)
# Print normalized data shape
print normalized_data.shape
# Inspect normalized data
print normalized_data
# Out:
# (1797L, 64L)
# [[ 0.          0.          0.09024036 ...,  0.          0.          0.        ]
#  [ 0.          0.          0.         ...,  0.15413829  0.          0.        ]
#  [ 0.          0.          0.         ...,  0.24153867  0.1358655   0.        ]
#  ...,
#  [ 0.          0.          0.0140138  ...,  0.08408278  0.          0.        ]
#  [ 0.          0.          0.03044313 ...,  0.18265877  0.          0.        ]
#  [ 0.          0.          0.14230641 ...,  0.17076769  0.01423064  0.        ]]

# %%
pca = PCA(n_components=2)
# Fit and transform the data to the model
reduced_data_pca = pca.fit_transform(normalized_data)
# Inspect the shape
reduced_data_pca.shape
# Print out the data
print reduced_data_pca
# Out:
# [[-0.02922966 -0.37782072]
#  [ 0.12773839  0.3169842 ]
#  [ 0.10978337  0.14534337]
#  ...,
#  [ 0.15085626  0.08573884]
#  [-0.08102208 -0.18243025]
#  [-0.00715628 -0.09883033]]

# %%
colors = ['black', 'blue', 'purple', 'yellow', 'white',
          'red', 'lime', 'cyan', 'orange', 'gray']
for i in range(len(colors)):
    x = reduced_data_pca[:, 0][digits.target == i]
    y = reduced_data_pca[:, 1][digits.target == i]
    plt.scatter(x, y, c=colors[i])
    plt.legend(digits.target_names, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
    plt.title("PCA Scatter Plot (Normalized Data)")
plt.show()
