# %%
from sklearn import datasets
digits = datasets.load_digits()
print(digits)
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-2-a33cc9bcb759> in <module>()
# ----> 1 from sklearn import datasets
#       2 digits = datasets.load_digits()
#       3 print(digits)
#
# C:\Users\Jose Antonio\Anaconda2\lib\site-packages\sklearn\datasets\__init__.py in <module>()
#      21 from .lfw import fetch_lfw_pairs
#      22 from .lfw import fetch_lfw_people
# ---> 23 from .twenty_newsgroups import fetch_20newsgroups
#      24 from .twenty_newsgroups import fetch_20newsgroups_vectorized
#      25 from .mldata import fetch_mldata, mldata_filename
#
# C:\Users\Jose Antonio\Anaconda2\lib\site-packages\sklearn\datasets\twenty_newsgroups.py in <module>()
#      53 from .base import RemoteFileMetadata
#      54 from ..utils import check_random_state, Bunch
# ---> 55 from ..feature_extraction.text import CountVectorizer
#      56 from ..preprocessing import normalize
#      57 from ..externals import joblib
#
# ...
